# %%
import os
import pandas as pd

# %%
# main directory for products data
dir = '../datalake/curated_zone/products/'

# %%
# method to get all files in a directory and its subdirectories

def get_all_files(
        dir: str
) -> pd.DataFrame:
    """
    Get all files in a directory and its subdirectories

    Args:
        dir(str): The main directory to search

    Return:
        pd.Dataframe: A dataframe wich contains all the files from 
        the subdirectories
    """

    all_dataframes = []

    # Walk through the directory tree
    for root, dirs, files in os.walk(dir):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)
                # Assuming each JSON file contains a DataFrame, read it
                try:
                    df = pd.read_json(file_path)
                    all_dataframes.append(df)

                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
    
    # Concatenate all DataFrames into a single DataFrame
    combined_df = pd.concat(
        all_dataframes, 
        ignore_index=True
    )

    return combined_df

# %%
# call methond to get all files in the directory
df = get_all_files(dir)

# %%
# get data types of the dataframe
df.dtypes
# Out:
# id                        int64
# title                    object
# price                   float64
# description              object
# category                 object
# image                    object
# rating.rate             float64
# rating.count              int64
# load_date                object
# category_tokenize        object
# title_tokenize           object
# description_tokenize     object
# category_stemm           object
# title_stemm              object
# description_stemm        object
# dtype: object

# %%
# get unique load_dates
unique_load_dates_df = sorted(df['load_date'].unique(), reverse=True)

print(pd.DataFrame({'Unique Load Dates': unique_load_dates_df}))
# Out:
#   Unique Load Dates
# 0        2024-01-21

# %%
# rename attributes
df = df.rename({ 
    'rating.rate': 'rating_rate', 
    'rating.count': 'rating_count'
  }, axis=1
)

# %%
# drop not needed attributes
df = df.drop([
    'category',
    'title', 
    'description',
  ], axis=1
)

# %%
# rearanage attributes
df = df[
    [
      'load_date',
      'id',
      'price',
      'rating_rate',
      'rating_count',
      'category_tokenize',
      'title_tokenize',
      'description_tokenize',
      'category_stemm',
      'title_stemm',
      'description_stemm'
    ]
]

# %%
# get first 5 rows of the dataframe
df.head(5)
# Out:
#     load_date  id   price  rating_rate  rating_count category_tokenize  \
# 0  2024-01-21   1  109.95          3.9           120   [men, clothing]
# 1  2024-01-21   2   22.30          4.1           259   [men, clothing]
# 2  2024-01-21   3   55.99          4.7           500   [men, clothing]
# 3  2024-01-21   4   15.99          2.1           430   [men, clothing]
# 4  2024-01-21   5  695.00          4.6           400        [jewelery]
#
#                                       title_tokenize  \
# 0    [fjallraven, foldsack, backpack, fits, laptops]
# 1                 [mens, casual, premium, slim, fit]
# 2                             [mens, cotton, jacket]
# 3                          [mens, casual, slim, fit]
# 4  [john, hardy, women, legends, naga, gold, silv...
#
#                                 description_tokenize category_stemm  \
# 0  [perfect, pack, everyday, use, walks, forest, ...   [men, cloth]
# 1  [style, contrast, raglan, long, sleeve, henley...   [men, cloth]
# 2  [great, outerwear, jackets, suitable, many, oc...   [men, cloth]
# 3  [color, could, slightly, different, screen, pr...   [men, cloth]
# 4  [legends, collection, naga, inspired, mythical...     [jeweleri]
#
#                                          title_stemm  \
# 0      [fjallraven, foldsack, backpack, fit, laptop]
# 1                  [men, casual, premium, slim, fit]
# 2                              [men, cotton, jacket]
# 3                           [men, casual, slim, fit]
# 4  [john, hardi, women, legend, naga, gold, silve...
#
#                                    description_stemm
# 0  [perfect, pack, everyday, use, walk, forest, s...
# 1  [style, contrast, raglan, long, sleev, henley,...
# 2  [great, outerwear, jacket, suitabl, mani, occa...
# 3  [color, could, slightli, differ, screen, pract...
# 4  [legend, collect, naga, inspir, mythic, water,...

# %%
# get last 5 rows of the dataframe
df.tail(5)
# Out:
#      load_date  id  price  rating_rate  rating_count  category_tokenize  \
# 15  2024-01-21  16  29.95          2.9           340  [women, clothing]
# 16  2024-01-21  17  39.99          3.8           679  [women, clothing]
# 17  2024-01-21  18   9.85          4.7           130  [women, clothing]
# 18  2024-01-21  19   7.95          4.5           146  [women, clothing]
# 19  2024-01-21  20  12.99          3.6           145  [women, clothing]
#
#                                        title_tokenize  \
# 15  [lock, love, women, removable, hooded, faux, l...
# 16  [rain, jacket, women, windbreaker, striped, cl...
# 17  [mbj, women, solid, short, sleeve, boat, neck, v]
# 18             [opna, women, short, sleeve, moisture]
# 19    [danvouy, womens, shirt, casual, cotton, short]
#
#                                  description_tokenize  category_stemm  \
# 15  [polyurethane, shell, polyester, lining, polye...  [women, cloth]
# 16  [lightweight, perfet, trip, casual, wear, slee...  [women, cloth]
# 17  [rayon, spandex, made, usa, imported, bleach, ...  [women, cloth]
# 18  [polyester, machine, wash, cationic, polyester...  [women, cloth]
# 19  [spandex, features, casual, short, sleeve, let...  [women, cloth]
#
#                                           title_stemm  \
# 15  [lock, love, women, remov, hood, faux, leather...
# 16  [rain, jacket, women, windbreak, stripe, climb...
# 17   [mbj, women, solid, short, sleev, boat, neck, v]
# 18               [opna, women, short, sleev, moistur]
# 19     [danvouy, women, shirt, casual, cotton, short]
#
#                                     description_stemm
# 15  [polyurethan, shell, polyest, line, polyest, c...
# 16  [lightweight, perfet, trip, casual, wear, slee...
# 17  [rayon, spandex, made, usa, import, bleach, li...
# 18  [polyest, machin, wash, cation, polyest, inter...
# 19  [spandex, featur, casual, short, sleev, letter...

# %%
# check for null values
df.isnull().sum()
# Out:
# load_date               0
# id                      0
# price                   0
# rating_rate             0
# rating_count            0
# category_tokenize       0
# title_tokenize          0
# description_tokenize    0
# category_stemm          0
# title_stemm             0
# description_stemm       0
# dtype: int64
